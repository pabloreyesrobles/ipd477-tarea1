# %%
import numpy as np
import matplotlib.pyplot as plt
import mne

from scipy.fft import fft, fftfreq
from scipy.io import loadmat
from scipy.signal import spectrogram
from mne.preprocessing import (ICA, create_eog_epochs,
                               create_ecg_epochs, corrmap)
from mne.externals.pymatreader import read_mat



# raw = mne.io.read_raw_fieldtrip('RawData.mat', eeg_mat.keys())
# raw.crop(tmax=60.)

# %%
eeg_mat = loadmat('RawData.mat')
ch_names = [f[0] for f in eeg_mat['locations']['labels'][0]]
ch_types = ['eeg'] * (len(ch_names) - 4) + ['eog'] * 4
sampling_freq = eeg_mat['sampling_rate'].ravel()[0]

info = mne.create_info(ch_names, ch_types=ch_types, sfreq=sampling_freq)

# %%
def center(x):
    mean = np.mean(x, axis=1, keepdims=True)
    centered =  x - mean
    return centered, mean

def covariance(x):
    mean = np.mean(x, axis=1, keepdims=True)
    n = np.shape(x)[1] - 1
    m = x - mean

    return (m.dot(m.T))/n

def whiten(x):
    # Calculate the covariance matrix
    coVarM = covariance(x)

    # Single value decoposition
    U, S, V = np.linalg.svd(coVarM)

    # Calculate diagonal matrix of eigenvalues
    d = np.diag(1.0 / np.sqrt(S))

    # Calculate whitening matrix
    whiteM = np.dot(U, np.dot(d, U.T))

    # Project onto whitening matrix
    Xw = np.dot(whiteM, x)

    return Xw, whiteM

x = eeg_mat['EEG_data'] * 1e-6

# Center signals
xc, ux = center(x)

# Whiten mixed signals
xw, wm = whiten(xc)

raw = mne.io.RawArray(xw, info)
raw
# Out:
# Creating RawArray with float64 data, n_channels=68, n_times=334848
#     Range : 0 ... 334847 =      0.000 ...   326.999 secs
# Ready.
# <RawArray | 68 x 334848 (327.0 s), ~173.8 MB, data loaded>

# %%
scalings = dict(eeg=20e-1, eog=150e-2)

plot = raw.plot(show_scrollbars=False, n_channels=68); #, scalings=scalings);
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
ica = ICA(n_components=30, max_iter='auto', random_state=0)
filt_raw = raw.copy().load_data().filter(l_freq=1., h_freq=None)
ica.fit(filt_raw)
ica
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 3381 samples (3.302 sec)
#
# Fitting ICA to data using 64 channels (please be patient, this may take a while)
# Selecting by number: 30 components
# Fitting ICA took 30.9s.
# <ICA | raw data decomposition, method: fastica (fit in 71 iterations on 334848 samples), 30 ICA components explaining 99.2 % of variance (64 PCA components available), channel types: eeg, no sources marked for exclusion>

# %%
raw.load_data()
ica.plot_sources(raw, show_scrollbars=False);
# Out:
# Creating RawArray with float64 data, n_channels=34, n_times=334848
#     Range : 0 ... 334847 =      0.000 ...   326.999 secs
# Ready.
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
exclude = ica.find_bads_eog(raw)[0];
ica.exclude = exclude
exclude
# Out:
# Using EOG channels: EXG1, EXG2, EXG3, EXG4
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 10240 samples (10.000 sec)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 10240 samples (10.000 sec)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 10240 samples (10.000 sec)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 10240 samples (10.000 sec)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 10240 samples (10.000 sec)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 10240 samples (10.000 sec)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 10240 samples (10.000 sec)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 10240 samples (10.000 sec)
# [4, 0]

# %%
ica.get_sources(filt_raw)
# Out:
# <RawArray | 30 x 334848 (327.0 s), ~76.7 MB, data loaded>

# %%
reconst_raw = raw.copy()
ica.apply(reconst_raw, n_pca_components=None)
raw.plot(show_scrollbars=False, n_channels=64);
reconst_raw.plot(show_scrollbars=False, n_channels=64);
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (30 components)
#     Zeroing out 2 ICA components
#     Projecting back using 64 PCA components
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
ica.plot_overlay(raw, exclude=exclude, picks='eeg');
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (30 components)
#     Zeroing out 2 ICA components
#     Projecting back using 64 PCA components

# %%
print(eeg_mat['EEG'])
eeg_mat['EEG'];
# Out:
# [[(array(['E11_EEG_espontaneo_Change Sampling Rate'], dtype='<U39'), array([[1024]], dtype=uint16), array([[68]], dtype=uint8), array([[(array(['Fp1'], dtype='<U3'), array([[1]], dtype=uint8), array([[90]], dtype=uint8), array([[-39]], dtype=int16)),
#           (array(['AF7'], dtype='<U3'), array([[1]], dtype=uint8), array([[-90]], dtype=int16), array([[-39]], dtype=int16)),
#           (array(['AF3'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['F1'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['F3'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['F5'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['F7'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['FT7'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['FC5'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['FC3'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['FC1'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['C1'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['C3'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['C5'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['T7'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['TP7'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['CP5'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['CP3'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['CP1'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P1'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P3'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P5'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P7'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P9'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['PO7'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['PO3'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['O1'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['Iz'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['Oz'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['POz'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['Pz'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['CPz'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['Fpz'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['Fp2'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['AF8'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['AF4'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['AFz'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['Fz'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['F2'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['F4'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['F6'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['F8'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['FT8'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['FC6'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['FC4'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['FC2'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['FCz'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['Cz'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['C2'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['C4'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['C6'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['T8'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['TP8'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['CP6'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['CP4'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['CP2'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P2'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P4'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P6'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P8'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['P10'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['PO8'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['PO4'], dtype='<U3'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['O2'], dtype='<U2'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['EXG1'], dtype='<U4'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['EXG2'], dtype='<U4'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['EXG3'], dtype='<U4'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8)),
#           (array(['EXG4'], dtype='<U4'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8))]],
#         dtype=[('labels', 'O'), ('sph_radius', 'O'), ('sph_theta', 'O'), ('sph_phi', 'O')]), array([[ 18.10546875,  18.40185547,  18.15527344, ...,  -6.24784803,
#            -7.0717392 ,  -7.12569904],
#          [ 11.3107605 ,  11.45144653,  12.39212036, ...,  -1.82017374,
#            -2.82984304,  -2.99244499],
#          [  0.1112442 ,  -0.50265884,   0.73623657, ...,  -3.96383166,
#            -3.65783334,  -3.4847095 ],
#          ...,
#          [ 14.39582062,  12.98843384,  11.79766083, ...,  -3.94097281,
#            -7.7846179 ,  -8.32248497],
#          [ 27.00634766,  26.93310547,  28.41259766, ...,  -5.61004066,
#            -4.35717916,  -3.87841177],
#          [-19.05358887, -18.60336304, -17.44125366, ...,   5.24350834,
#             2.49288344,   1.67690647]]), array([[334848]], dtype=int32), array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([[326.99902344]]), array(['common'], dtype='<U6'), array([[(array(['S225'], dtype='<U4'), array(['Stimulus'], dtype='<U8'), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#           (array(['R255'], dtype='<U4'), array(['Response'], dtype='<U8'), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[2]], dtype=uint8)),
#           (array(['Speed Mode 6'], dtype='<U12'), array(['Comment'], dtype='<U7'), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[3]], dtype=uint8)),
#           (array(['Start Epoch'], dtype='<U11'), array(['Comment'], dtype='<U7'), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[4]], dtype=uint8)),
#           (array(['CMS in range'], dtype='<U12'), array(['Comment'], dtype='<U7'), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[5]], dtype=uint8)),
#           (array(['ActiveTwo MK2'], dtype='<U13'), array(['Comment'], dtype='<U7'), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[6]], dtype=uint8))]],
#         dtype=[('type', 'O'), ('code', 'O'), ('duration', 'O'), ('latency', 'O'), ('urevent', 'O')]), array([[(array(['S225'], dtype='<U4'), array(['Stimulus'], dtype='<U8'), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#           (array(['R255'], dtype='<U4'), array(['Response'], dtype='<U8'), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#           (array(['Speed Mode 6'], dtype='<U12'), array(['Comment'], dtype='<U7'), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#           (array(['Start Epoch'], dtype='<U11'), array(['Comment'], dtype='<U7'), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#           (array(['CMS in range'], dtype='<U12'), array(['Comment'], dtype='<U7'), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#           (array(['ActiveTwo MK2'], dtype='<U13'), array(['Comment'], dtype='<U7'), array([[1]], dtype=uint8), array([[1]], dtype=uint8))]],
#         dtype=[('type', 'O'), ('code', 'O'), ('duration', 'O'), ('latency', 'O')]))                                                                                                                                                                                                                                                               ]]
